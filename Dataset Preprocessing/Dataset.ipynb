# %%
import pandas as pd

df = pd.read_excel("C:/Users/amine/Documents/Code/vs code/INSE6220/ENB2012_data.xlsx")
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
print(df['Y1'].min(), df['Y1'].max())
# Out:
# 6.01 43.1

# %%
import matplotlib.pyplot as plt

plt.hist(df['Y1'], bins=100)
plt.title('Heating Load Distribution')
plt.xlabel('Heating Load (Y1)')
plt.ylabel('Count')
plt.show()

# %%
df['class'] = pd.cut(df['Y1'], bins=[0, 14.55, 28.6, df['Y1'].max()], labels=[ 1, 2, 3], include_lowest=True)

# %%
df['class'].value_counts()
# Out:
# class
# 3    259
# 1    258
# 2    251
# Name: count, dtype: int64

# %%
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2 class
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33     2
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33     2
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33     2
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33     2
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28     2
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...   ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40     2
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88     2
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11     2
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61     2
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03     2
#
# [768 rows x 11 columns]

# %%
df = df.drop(columns=['Y1', 'Y2'])

# %%
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8 class
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0     2
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0     2
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0     2
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0     2
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0     2
# ..    ...    ...    ...     ...  ...  ..  ...  ..   ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5     2
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5     2
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5     2
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5     2
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5     2
#
# [768 rows x 9 columns]

# %%
df.to_csv('C:/Users/amine/Documents/Code/vs code/INSE6220/ENB2012_data.csv', index=False)
